# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os

data= pd.read_csv("phr2.csv", dtype=float)
data=data.dropna(axis=0,how='any')
data.ph1[data['ph1']<0.1]=0
data.ph1[data['ph1']>=0.1]=1
#dataplot = data.drop(['ndwi','evi','d1ndwi','d2ndwi','d1evi','d2evi','temp','soilmo','sat0','sat1','sat2','sat3','sat4','d1prec','d2prec','prec','d1ndvi','d2ndvi','ndvi','d1temp','d2temp','evapot','elevation','gwlvl','t1','t2','d1sat0','d2sat0','d1sat1','d2sat1','d1sat2','d2sat2','d1sat3','d2sat3','d1sat4','d2sat4'], axis=1)
#dataplot= data.drop(['d1ndwi','d2ndwi','d1evi','d2evi','d1prec','d2prec','d1ndvi','d2ndvi','d1temp','d2temp','evapot','elevation','gwlvl','t1','t2','d1sat0','d2sat0','d1sat1','d2sat1','d1sat2','d2sat2','d1sat3','d2sat3','d1sat4','d2sat4'], axis=1)
#dataplot = data.drop(['temp','soilmo','sat0','sat1','sat2','sat3','sat4','d1prec','d2prec','prec','d1ndvi','d2ndvi','ndvi','d1temp','d2temp','evapot','elevation','gwlvl','truth','d1sat0','d2sat0','d1sat1','d2sat1','d1sat2','d2sat2','d1sat3','d2sat3','d1sat4','d2sat4'], axis=1)
dataplot=data.drop('ph2',axis=1)
dataplot = dataplot[dataplot['ph1']>=0.2]
dataplot
# Out:
#             x      y  ph1
# 19        0.0   38.0  1.0
# 21        0.0   42.0  1.0
# 176       0.0  352.0  1.0
# 177       0.0  354.0  1.0
# 178       0.0  356.0  1.0
# 179       0.0  358.0  1.0
# 296       0.0  592.0  1.0
# 298       0.0  596.0  1.0
# 300       0.0  600.0  1.0
# 483       2.0   38.0  1.0
# 574       2.0  220.0  1.0
# 575       2.0  222.0  1.0
# 636       2.0  344.0  1.0
# 637       2.0  346.0  1.0
# 638       2.0  348.0  1.0
# 639       2.0  350.0  1.0
# 641       2.0  354.0  1.0
# 643       2.0  358.0  1.0
# 644       2.0  360.0  1.0
# 763       2.0  598.0  1.0
# 764       2.0  600.0  1.0
# 765       2.0  602.0  1.0
# 766       2.0  604.0  1.0
# 767       2.0  606.0  1.0
# 1038      4.0  220.0  1.0
# 1098      4.0  340.0  1.0
# 1099      4.0  342.0  1.0
# 1100      4.0  344.0  1.0
# 1101      4.0  346.0  1.0
# 1102      4.0  348.0  1.0
# ...       ...    ...  ...
# 156930  676.0  196.0  1.0
# 156992  676.0  320.0  1.0
# 157056  676.0  448.0  1.0
# ...

# %%
x= dataplot['x']
y= dataplot['y']
yi

# %%
data.plot(kind="scatter",x="y",y="x",alpha=0.4,c="ph1",figsize=(10,7))
